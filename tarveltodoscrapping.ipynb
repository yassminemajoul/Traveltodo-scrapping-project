# %%
from bs4 import BeautifulSoup
from bs4.element import NavigableString
import json
import re
import requests
import pandas as pd
import nest_asyncio
import asyncio
from playwright.async_api import async_playwright
from playwright.async_api import TimeoutError

# %%
nest_asyncio.apply()  # Allow nested loops in Jupyter/Colab

async def load_and_click_return_html(url: str):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        await page.goto(url)

        # Use the button class and text to locate it precisely
        await page.wait_for_selector('button.btn.btn-info.btn-block', timeout=10000)

        # Optional: Confirm it's the right button by checking text content
        buttons = await page.query_selector_all('button.btn.btn-info.btn-block')
        for btn in buttons:
            text = await btn.text_content()
            if "Vérifier la disponibilité" in text:
                await btn.click()
                break

        # Wait for any dynamic content to load after click
        await page.wait_for_timeout(2000)

        html = await page.content()
        await browser.close()
        return html

# %%
def extract_hotel_info(html):
    soup = BeautifulSoup(html, 'html.parser')

    # URL
    url_tag = soup.find('link', rel='canonical')
    url = url_tag['href'] if url_tag else None

    # Name
    name_tag = soup.find('meta', property='og:title')
    name = name_tag['content'] if name_tag else None

    # Star rating
    stars_tag = soup.find('meta', property='og:category')
    stars_rating = None
    if stars_tag:
        match = re.search(r'(\d)', stars_tag['content'])
        stars_rating = int(match.group(1)) if match else None

    # Initialize fields
    avis = latitude = longitude = location = None

    # Find JSON-LD with hotel info
    json_ld_tags = soup.find_all('script', type='application/ld+json')
    for tag in json_ld_tags:
        try:
            data = json.loads(tag.string)
            if isinstance(data, dict) and data.get('@type') == 'Hotel':
                avis = data.get('aggregateRating', {}).get('ratingValue')
                latitude = data.get('geo', {}).get('latitude')
                longitude = data.get('geo', {}).get('longitude')
                address = data.get('address', {})
                locality = address.get('addressLocality')
                country = address.get('addressCountry')
                location = f"{locality}" if locality else None
                break
        except (json.JSONDecodeError, TypeError):
            continue

    # Extract services
    services_div = soup.find('div', class_='row row-cols-2 row-cols-lg-4 g-2 g-lg-3 mb-3')
    services = []
    if services_div:
        services = [div.get_text(strip=True) for div in services_div.find_all('div', class_='col')]

    # Extract price from the specific price div
    price_div = soup.find('div', class_='text-end col-md-2 col-5 price font-weight-600 fs-6 selected')
    price = None
    if price_div:
        text = price_div.get_text()
        match = re.search(r'(\d+(?:\.\d+)?)', text)
        if match:
            price = float(match.group(1))

    return [url, name, stars_rating, avis, location, latitude, longitude, services, price]

# %%
#Extracting All hotel Links from each city

# URL dictionary for destinations
destinations = {
     "Tunis": "https://www.traveltodo.com/sejours-en-tunisie/hotels/hotel-tunis/",
    "Hammamet": "https://www.traveltodo.com/sejours-en-tunisie/hotels/hotel-hammamet/",
    "Korba": "https://www.traveltodo.com/sejours-en-tunisie/hotels/hotel-korba/",
    "Nabeul": "https://www.traveltodo.com/sejours-en-tunisie/hotels/hotel-nabeul/",
    "Korbous": "https://www.traveltodo.com/sejours-en-tunisie/hotels/hotel-korbous/",
    "Sousse": "https://www.traveltodo.com/sejours-en-tunisie/hotels/hotel-sousse/",
    "Monastir": "https://www.traveltodo.com/sejours-en-tunisie/hotels/hotel-monastir/",
    "Mahdia": "https://www.traveltodo.com/sejours-en-tunisie/hotels/hotel-mahdia/",
    "Tabarka": "https://www.traveltodo.com/sejours-en-tunisie/hotels/hotel-tabarka/",
    "Ain Draham": "https://www.traveltodo.com/sejours-en-tunisie/hotels/hotel-ain-draham/",
    "Tozeur": "https://www.traveltodo.com/sejours-en-tunisie/hotels/hotel-tozeur/",
    "Djerba": "https://www.traveltodo.com/sejours-en-tunisie/hotels/hotel-djerba/" ,  # Replace with actual URL
    # Add more cities and their URLs as needed
}

base_url = "https://www.traveltodo.com"  # The base URL for the links

all_hotels = []  # List to store all hotels' details

# Loop through each destination
for city, url in destinations.items():
    print(f"Scraping {city}...")
    try:
        response = requests.get(url)  # Send request to the webpage
        soup = BeautifulSoup(response.text, "html.parser")

        # Find all hotel blocks (h3 with class "text-capitalize")
        hotel_blocks = soup.find_all("h3", class_="text-capitalize")

        for block in hotel_blocks:
            # Extract hotel name
            a_tag = block.find("a")
            if a_tag:
                name = a_tag.get_text(strip=True)
                link = base_url + a_tag["href"]  # Full link to the hotel page
            else:
                name = 'Name not found'
                link = 'Link not available'

            

            # Append hotel details to the list
            all_hotels.append(link)

    except Exception as e:
        print(f"Failed to scrape {city}: {e}")
# Out:
# Scraping Tunis...
# Scraping Hammamet...
# Scraping Korba...
# Scraping Nabeul...
# Scraping Korbous...
# Scraping Sousse...
# Scraping Monastir...
# Scraping Mahdia...
# Scraping Tabarka...
# Scraping Ain Draham...
# Scraping Tozeur...
# Scraping Djerba...

# %%
# all_hotels

# %%
# Collect all data rows here
all_data = []

# x = 4
# stop_after_x = True


print(len(all_hotels))


z=237
for i in range(237,len(all_hotels)):
    html = await load_and_click_return_html(all_hotels[i])
    data = extract_hotel_info(html)
    all_data.append(data)
    print(data)
    z=z+1
    print(z)
    # if i == x and stop_after_x == True:
    #     break
    

# Define column names
columns = [
    "url", "name", "stars_rating", "avis",
    "location", "latitude", "longitude", "services","price"
]

# Create DataFrame
df = pd.DataFrame(all_data, columns=columns)

# Optionally convert 'services' list to string for CSV
df['services'] = df['services'].apply(lambda x: ', '.join(x) if isinstance(x, list) else '')

# Save to CSV
df.to_csv("hotels_data.csv", index=False, encoding="utf-8-sig")
# Out:
# 278
# ['https://www.traveltodo.com/hotels-tunisie/djerba/club-med-djerba-la-douce-1236.html', 'Club Med Djerba la Douce', 4, None, 'Djerba', 33.780565, 11.04851, ['Bar', 'Restaurant', 'Plage', 'Café', 'Discothèque', 'Salle de réunion', 'Piscine', 'Télévision', 'Chaînes câblées', 'Tennis', 'Sports nautiques', 'Change'], None]
# 238
# ['https://www.traveltodo.com/hotels-tunisie/djerba/alkantara-thalasso-djerba-1349.html', 'Alkantara Thalasso Djerba', 4, '12', 'Djerba', None, None, ['Climatisation', 'Sèche-cheveux', 'Bar', 'Restaurant', 'Plage', 'Salle de réunion', 'Piscine', 'Télévision', 'Sports nautiques'], None]
# 239
# ['https://www.traveltodo.com/hotels-tunisie/djerba/aldiana-djerba-atlantide-2143.html', 'Aldiana Djerba Atlantide', 4, None, 'Djerba', None, None, [], 655.5]
# 240
# ['https://www.traveltodo.com/hotels-tunisie/djerba/tui-magic-life-penelope-1325.html', 'Tui Magic Life Penelope', 4, '15', 'Djerba', 33.8457648, 10.993065, ['Climatisation', "Garderie d'enfants", 'Téléphone avec ligne directe', 'Bar', 'Restaurant', 'Plage', 'Club de remise en forme', 'Coffre fort', 'Café', 'Massage', 'Discothèque', 'Piscine', 'Ascenseur', 'Télévision', 'Chaînes câblées', 'Tennis', 'Chambre non fumeur', 'Sports nautiques', 'Change'], None]
# 241
# ['https://www.traveltodo.com/hotels-tunisie/djerba/seabel-rym-beach-djerba-247.html', 'Hôtel Seabel Rym Beach Djerba 4*', 4, '16', 'Djerba', 33.827195, 11.046544, ['Climatisation', 'Bar', 'Restaurant', 'Plage', 'Sauna', 'Piscine', 'Ascenseur', 'Boutique de cadeaux', 'Golf'], None]
# 242
# ['https://www.traveltodo.com/hotels-tunisie/djerba/djerba-castille-1331.html', 'Djerba Castille-Traveltodo', 4, '12', 'Djerba', 33.765317, 11.023228, ['Climatisation', 'Téléphone avec ligne directe', 'Bar', 'Restaurant', 'Plage', 'Service de blanchisserie', 'Café', 'Discothèque', 'Piscine', 'Télévision'], None]
# 243
# ['https://www.traveltodo.com/hotels-tunisie/djerba/residence-de-charme-djerba-explore-2200.html', 'Residence de charme Djerba Explore', 4, None, 'Djerba', None, None, [], 228.8]
# 244
# ['https://www.traveltodo.com/hotels-tunisie/djerba/iris-djerba-hotel-thalasso-1431.html', 'Iris Djerba Hôtel & Thalasso-Traveltodo', 4, '11', 'Djerba', None, None, ['Climatisation', 'Sèche-cheveux', 'Téléphone avec ligne directe', 'Bar', 'Restaurant', 'Plage', 'Café', 'Massage', 'Centre de remise en forme', 'Piscine', 'Ascenseur', 'Télévision', 'Golf', 'Change'], None]
# 245
# ['https://www.traveltodo.com/hotels-tunisie/djerba/turismark-marine-beach-2105.html', 'Turismark Marine Beach', 4, None, 'Djerba', None, None, [], 35.0]
# 246
# ['https://www.traveltodo.com/hotels-tunisie/djerba/robinson-club-djerba-bahiya-1699.html', 'ROBINSON CLUB DJERBA BAHIYA', 4, '16', 'Djerba', 11.0513881, 33.8230864, [], 880.0]
# 247
# ['https://www.traveltodo.com/hotels-tunisie/djerba/le-petit-palais-spa-910.html', 'Le Petit Palais & Spa -Traveltodo', 4, '14', 'Djerba', 33.855279, 10.982357, ['Climatisation', 'Bar', 'Restaurant', 'Plage', 'Club de remise en forme', 'Café', 'Massage', 'Piscine', 'Tennis'], 235.2]
# 248
# ['https://www.traveltodo.com/hotels-tunisie/djerba/cesar-thalasso-912.html', 'Cesar Thalasso', 4, '14', 'Djerba', 33.833693, 11.007573, ['Climatisation', 'Coiffeur', 'Téléphone avec ligne directe', 'Bar', 'Restaurant', 'Plage', 'Club de remise en forme', 'Salon de Beauté', 'Coffre fort', 'Sauna', 'Casino', 'Café', 'Massage', 'Centre de remise en forme', 'Discothèque', 'Salle de réunion', 'Piscine', 'Télévision', 'Tennis', 'Sports nautiques', 'Boutique de cadeaux', 'Golf', 'Change'], 218.5]
# 249
# ['https://www.traveltodo.com/hotels-tunisie/djerba/djerba-aqua-resort-911.html', 'Djerba Aqua Resort', 4, '14', 'Djerba', 33.832799, 11.005064, ['Climatisation', "Garderie d'enfants", 'Coiffeur', 'Téléphone avec ligne directe', 'Bar', 'Restaurant', 'Plage', 'Salon de Beauté', 'Coffre fort', "Centre d'affaires", 'Sauna', 'Service de blanchisserie', 'Café', 'Massage', 'Salle de réunion', 'Piscine', 'Télévision', 'Tennis', 'Sports nautiques', 'Boutique de cadeaux', 'Golf', 'Change'], 195.5]
# 250
# ['https://www.traveltodo.com/hotels-tunisie/djerba/djerba-resort-1104.html', 'Djerba Resort', 4, '13', 'Djerba', 33.839963, 10.993692, ['Climatisation', 'Sèche-cheveux', 'Bar', 'Restaurant', 'Plage', 'Café', 'Piscine', 'Ascenseur', 'Boutique de cadeaux'], 249.55]
# 251
# ['https://www.traveltodo.com/hotels-tunisie/djerba/djerba-sun-beach-1087.html', 'Djerba Sun Beach -Traveltodo', 4, '14', 'Djerba', 33.859967, 10.975513, ['Climatisation', "Garderie d'enfants", 'Coiffeur', 'Bar', 'Plage', 'Coffre fort', 'Casino', 'Café', 'Centre de remise en forme', 'Discothèque', 'Chaînes câblées', 'Boutique de cadeaux', 'Parking gratuit'], 20.0]
# 252
# ['https://www.traveltodo.com/hotels-tunisie/djerba/fiesta-beach-1825.html', 'Fiesta Beach', 4, '15', 'Djerba', 10.985759, 33.8494594, [], 312.8]
# 253
# ['https://www.traveltodo.com/hotels-tunisie/djerba/el-mouradi-djerba-menzel-702.html', 'Hôtel  El mouradi djerba menzel', 4, '14', 'Djerba', 33.78032, 11.053472, ['Climatisation', 'Sèche-cheveux', 'Téléphone avec ligne directe', 'Bar', 'Restaurant', 'Plage', 'Club de remise en forme', 'Salon de Beauté', "Centre d'affaires", 'Sauna', 'Café', 'Centre de congrès', 'Massage', 'Centre de remise en forme', 'Discothèque', 'Salle de réunion', 'Piscine', 'Télévision', 'Chaînes câblées', 'Tennis', 'Sports nautiques', 'Boutique de cadeaux', 'Golf', 'Change'], 11.8]
# 254
# ['https://www.traveltodo.com/hotels-tunisie/djerba/the-ksar-djerba-charming-hotel-spa-1002.html', 'The Ksar Djerba Charming Hôtel & Spa-Traveltodo', 4, '13', 'Djerba', 33.841954, 10.995487, ['Climatisation', "Garderie d'enfants", 'Bar', 'Restaurant', 'Plage', 'Club de remise en forme', 'Coffre fort', 'Café', 'Massage', 'Piscine', 'Tennis', 'Sports nautiques', 'Boutique de cadeaux', 'Golf', 'Change'], 195.5]
# 255
# ['https://www.traveltodo.com/hotels-tunisie/djerba/royal-karthago-resort-thalasso-1751.html', 'Royal Karthago Resort &thalasso -Traveltodo', 4, '16', 'Djerba', 33.80813, 10.99228, [], 322.0]
# 256
# ['https://www.traveltodo.com/hotels-tunisie/djerba/caribbean-world-djerba-thalasso-1451.html', 'Caribbean World Djerba Thalasso', 4, '16', 'Djerba', 10.9832091, 33.8560804, ['Climatisation', 'Sèche-cheveux', 'Bar', 'Restaurant', 'Plage', 'Sauna', 'Café', 'Massage', 'Piscine', 'Télévision', 'Sports nautiques', 'Boutique de cadeaux', 'Change'], 369.6]
# 257
# ['https://www.traveltodo.com/hotels-tunisie/djerba/club-calimera-yati-beach-1366.html', 'Club Calimera Yati Beach', 4, '16', 'Djerba', 33.8273783, 11.0488558, ['Climatisation', 'Bar', 'Restaurant', 'Plage', 'Café', 'Piscine', 'Télévision'], 10.0]
# 258
# ['https://www.traveltodo.com/hotels-tunisie/djerba/welcome-meridiana-1521.html', 'Welcome Meridiana -Traveltodo', 4, '14', 'Djerba', 33.8283987, 11.0381099, ['Climatisation', 'Téléphone avec ligne directe', 'Bar', 'Restaurant', 'Plage', 'Café', 'Piscine', 'Télévision'], 552.0]
# 259
# ['https://www.traveltodo.com/hotels-tunisie/djerba/hari-club-beach-resort-1773.html', 'Hari Club Beach Resort', 4, '10', 'Djerba', 33.7709603, 11.0278071, [], 25.0]
# 260
# ['https://www.traveltodo.com/hotels-tunisie/djerba/hotel-club-palm-azur-1334.html', 'Hôtel Club Palm Azur-Traveltodo', 4, '15', 'Djerba', 33.762448, 11.020814, ['Sèche-cheveux', 'Téléphone avec ligne directe', 'Bar', 'Restaurant', 'Plage', "Centre d'affaires", 'Sauna', 'Café', 'Massage', 'Centre de remise en forme', 'Discothèque', 'Salle de réunion', 'Piscine', 'Télévision', 'Chaînes câblées', 'Sports nautiques'], 40.0]
# 261
# ['https://www.traveltodo.com/hotels-tunisie/djerba/vincci-helios-beach-spa-1239.html', 'Vincci Helios Beach & Spa-Traveltodo', 4, '16', 'Djerba', 33.81818, 11.053067, ['Climatisation', 'Bar', 'Discothèque', 'Piscine', 'Ascenseur', 'Chaînes câblées', 'Change'], 448.5]
# 262
# ['https://www.traveltodo.com/hotels-tunisie/djerba/telemaque-beach-spa-1714.html', 'TELEMAQUE BEACH &SPA', 4, '18', 'Djerba', 33.8614514, 10.9758704, [], 343.2]
# 263
# ['https://www.traveltodo.com/hotels-tunisie/djerba/vincci-dar-midoun-spa-2042.html', 'Vincci Dar Midoun & Spa-Traveltodo', 4, '12', 'Djerba', 10.9938497, 33.8441, [], 299.0]
# 264
# ['https://www.traveltodo.com/hotels-tunisie/djerba/djerba-holiday-beach-1657.html', 'Djerba Holiday Beach', 4, '08', 'Djerba', 33.8706529, 10.9385151, ['Climatisation', 'Bar', 'Plage', 'Café', 'Massage', 'Centre de remise en forme', 'Piscine', 'Ascenseur'], 281.6]
# 265
# ['https://www.traveltodo.com/hotels-tunisie/djerba/grand-hotel-des-thermes-1669.html', 'Grand Hôtel Des Thermes', 4, '12', 'Djerba', None, None, ['Climatisation', 'Bar', 'Equipements pour handicapés', 'Restaurant', 'Salon de Beauté', 'Coffre fort', 'Sauna', 'Café', 'Massage', 'Centre de remise en forme', 'Piscine', 'Ascenseur', 'Boutique de cadeaux'], 107.8]
# 266
# ['https://www.traveltodo.com/hotels-tunisie/sousse/riadh-palms-resort-and-spa-897.html', 'Riadh Palms Resort and Spa', 4, None, 'Sousse', 35.841438, 10.629605, ['Climatisation', 'Sèche-cheveux', 'Coiffeur', 'Bar', 'Restaurant', 'Plage', 'Salon de Beauté', 'Coffre fort', "Centre d'affaires", 'Sauna', 'Casino', 'Service de blanchisserie', 'Café', 'Centre de congrès', 'Massage', 'Centre de remise en forme', 'Discothèque', 'Salle de réunion', 'Piscine', 'Ascenseur', 'Télévision', 'Chaînes câblées', 'Boutique de cadeaux', 'Change', 'Wifi gratuit dans les chambres', 'Wifi gratuit dans le hall de réception'], 19.0]
# 267
# ['https://www.traveltodo.com/hotels-tunisie/djerba/djerba-golf-resort-spa-1768.html', 'Djerba Golf Resort & spa', 4, '13', 'Djerba', None, None, ['Climatisation', "Garderie d'enfants", 'Coiffeur', 'Bar', 'Restaurant', 'Plage', 'Salon de Beauté', 'Café', 'Centre de congrès', 'Centre de remise en forme', 'Discothèque', 'Piscine', 'Ascenseur', 'Chaînes câblées', 'Tennis', 'Sports nautiques', 'Change', 'Parking gratuit'], 30.0]
# 268
# ['https://www.traveltodo.com/hotels-tunisie/djerba/sentido-djerba-beach-1058.html', 'Sentido Djerba Beach-Traveltodo', 4, '16', 'Djerba', 33.842562, 10.998573, ['Climatisation', 'Bar', 'Restaurant', 'Café', 'Piscine', 'Ascenseur', 'Télévision', 'Boutique de cadeaux'], 381.23]
# 269
# ['https://www.traveltodo.com/hotels-tunisie/djerba/riad-meninx-1737.html', 'Riad Meninx', 4, None, 'Djerba', 33.8366664, 11.0001851, [], None]
# 270
# ['https://www.traveltodo.com/hotels-tunisie/djerba/iberostar-waves-mehari-djerba-1008.html', 'Iberostar Waves Mehari Djerba -Traveltodo', 4, '16', 'Djerba', 33.8271247, 11.0183922, ['Climatisation', 'Bar', 'Restaurant', 'Plage', 'Club de remise en forme', 'Service de blanchisserie', 'Café', 'Massage', 'Centre de remise en forme', 'Discothèque', 'Piscine', 'Ascenseur', 'Télévision', 'Chaînes câblées', 'Boutique de cadeaux', 'Change'], 684.94]
# 271
# ['https://www.traveltodo.com/hotels-tunisie/djerba/djerba-plaza-thalasso-spa-1110.html', 'Djerba Plaza Thalasso & Spa', 4, '17', 'Djerba', 33.8309588, 11.0082581, ['Climatisation', 'Téléphone avec ligne directe', 'Restaurant', 'Plage', 'Club de remise en forme', 'Coffre fort', 'Sauna', 'Centre de congrès', 'Massage', 'Centre de remise en forme', 'Discothèque', 'Salle de réunion', 'Piscine', 'Télévision'], 20.0]
# 272
# ['https://www.traveltodo.com/hotels-tunisie/djerba/golf-beach-thalasso-2141.html', 'Golf Beach & Thalasso', 4, '12', 'Djerba', 33.8006283, 10.9825769, [], 253.0]
# 273
# ['https://www.traveltodo.com/hotels-tunisie/djerba/djerba-golf-resort-spa-1768.html', 'Djerba Golf Resort & spa', 4, '13', 'Djerba', None, None, ['Climatisation', "Garderie d'enfants", 'Coiffeur', 'Bar', 'Restaurant', 'Plage', 'Salon de Beauté', 'Café', 'Centre de congrès', 'Centre de remise en forme', 'Discothèque', 'Piscine', 'Ascenseur', 'Chaînes câblées', 'Tennis', 'Sports nautiques', 'Change', 'Parking gratuit'], 30.0]
# 274
# ['https://www.traveltodo.com/hotels-tunisie/djerba/joya-paradise-1682.html', 'Joya Paradise', 4, '11', 'Djerba', 33.8247423, 10.8786056, ['Climatisation', 'Sèche-cheveux', "Garderie d'enfants", 'Bar', 'Restaurant', 'Plage', 'Salon de Beauté', 'Coffre fort', 'Centre de remise en forme', 'Piscine', 'Télévision', 'Boutique de cadeaux', 'Wifi gratuit dans les chambres', 'Parking gratuit'], 200.0]
# 275
# ['https://www.traveltodo.com/hotels-tunisie/djerba/venice-beach-1692.html', 'Venice Beach-Traveltodo', 3, '14', 'Djerba', None, None, [], 33.0]
# 276
# ['https://www.traveltodo.com/hotels-tunisie/djerba/seabel-aladin-djerba-1471.html', 'Seabel Aladin Djerba', 3, '15', 'Djerba', 11.0191514, 33.7643998, ['Climatisation', 'Coiffeur', 'Bar', 'Restaurant', 'Plage', 'Café', 'Discothèque', 'Piscine', 'Télévision', 'Sports nautiques', 'Boutique de cadeaux'], 330.05]
# 277
# ['https://www.traveltodo.com/hotels-tunisie/djerba/saray-djerba-1677.html', 'Saray Djerba-Traveltodo', 3, '14', 'Djerba', None, None, [], 138.0]
# 278

# %%
# import folium
# import pandas as pd

# def pin_all_hotels_on_map(df, map_file='hotels_map.html'):
#     Center the map around the average Location
#     center_lat = df['latitude'].mean()
#     center_lon = df['longitude'].mean()

#     hotel_map = folium.Map(location=[center_lat, center_lon], zoom_start=10)

#     Loop through DataFrame and add a marker for each hotel
#     for _, row in df.iterrows():
#         if pd.notnull(row['latitude']) and pd.notnull(row['longitude']):
#             popup_text = f'<b>{row["name"]}</b><br>{row["stars_rating"]}⭐<br>{row["location"]}'
#             folium.Marker(
#                 location=[row['latitude'], row['longitude']],
#                 popup=folium.Popup(popup_text, max_width=250),
#                 tooltip=row['name']
#             ).add_to(hotel_map)

#     hotel_map.save(map_file)
#     print(f"Map saved as {map_file}")

# %%
 #pin_all_hotels_on_map(df, map_file='hotels_map.html')
